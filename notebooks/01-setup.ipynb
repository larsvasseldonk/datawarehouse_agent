# %% [markdown]
# # Setup Test
#
# Run each cell in order. If the last cell prints a response, your environment is working.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

openai_client = OpenAI()

# %%
response = openai_client.responses.create(
    model="gpt-4o-mini",
    input="Say hello in one short sentence."
)

print(response.output_text)
# Out:
# Hello!

# %%
import os
import urllib.request

import duckdb

DATA_URL = "https://blobs.duckdb.org/nl-railway/services-2025-03.csv.gz"
CSV_FILE = "services-2025-03.csv.gz"

con = duckdb.connect("dutch_railways.db")


def setup_database():
    """Download the CSV file and load it into DuckDB."""
    # if not os.path.exists(CSV_FILE):
    #     print(f"Downloading {DATA_URL}...")
    #     urllib.request.urlretrieve(DATA_URL, CSV_FILE)

    con.execute(f"""
        CREATE TABLE IF NOT EXISTS services AS
        SELECT * FROM '{DATA_URL}'
    """)
    count = con.execute("SELECT COUNT(*) FROM services").fetchone()[0]
    print(f"Loaded {count} rows")
    return count

# %%
setup_database()
# Out:
# Downloading https://blobs.duckdb.org/nl-railway/services-2025-03.csv.gz...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 setup_database()
#
# Cell In[6], line 16, in setup_database()
#      12 def setup_database():
#      13     """Download the CSV file and load it into DuckDB."""
#      14     if not os.path.exists(CSV_FILE):
#      15         print(f"Downloading {DATA_URL}...")
# ---> 16         urllib.request.urlretrieve(DATA_URL, CSV_FILE)
#      17
#      18     con.execute(f"""
#      19         CREATE TABLE IF NOT EXISTS services AS
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:214, in urlretrieve(url, filename, reporthook, data)
#     197 """
#     198 Retrieve a URL into a temporary location on disk.
#     199
#    (...)    210 data file as well as the resulting HTTPMessage object.
#     211 """
#     212 url_type, path = _splittype(url)
# --> 214 with contextlib.closing(urlopen(url, data)) as fp:
#     215     headers = fp.info()
#     217     # Just return the local path and the "headers" for file://
#     218     # URLs. No sense in performing a copy unless requested.
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden
